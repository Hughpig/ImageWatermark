# %%
import sys
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 假设核心模块已经导入
# from core import transform, protect, watermark
# from experiments import metrics, attack_test

plt.rcParams['font.sans-serif'] = ['SimHei'] # 用于正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False # 用于正常显示负号

# %% [markdown]
# # 第1部分：引入核心模块与依赖库
# 导入项目中的核心算法模块、评估指标模块以及必要的第三方库（NumPy, OpenCV, Matplotlib 等）。
